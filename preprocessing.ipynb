# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/train.csv')

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  9117000170  20150505T000000  268643         4       2.25         1810
# 1  6700390210  20140708T000000  245000         3       2.50         1600
# 2  7212660540  20150115T000000  200000         4       2.50         1720
# 3  8562780200  20150427T000000  352499         2       2.25         1240
# 4  7760400350  20141205T000000  232000         3       2.00         1280
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      9240     2.0           0     0  ...      7        1810              0
# 1      2788     2.0           0     0  ...      7        1600              0
# 2      8638     2.0           0     0  ...      8        1720              0
# 3       705     2.0           0     0  ...      7        1150             90
# 4     13356     1.0           0     0  ...      7        1280              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1961             0    98055  47.4362 -122.187           1660
# 1      1992             0    98031  47.4034 -122.187           1720
# 2      1994             0    98003  47.2704 -122.313           1870
# 3      2009             0    98027  47.5321 -122.073           1240
# 4      1994             0    98042  47.3715 -122.074           1590
#
#    sqft_lot15
# 0        9240
# 1        3605
# 2        7455
# 3         750
# 4        8071
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (16209, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.drop(columns=['id', 'date'],inplace=True)

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['price'], bins=50, kde=True)
plt.title("Distribution of House Prices")
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.boxplot(x=df['price'])
plt.title("Boxplot of House Prices")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['sqft_living'], y=df['price'], alpha=0.4)
plt.title("sqft_living vs price")
plt.show()

# %%
area_cols = [col for col in df.columns if col.startswith('sqft')]

n_cols = 3
n_rows = 3

fig = plt.figure(figsize=(4 * n_cols, 4 * n_rows), facecolor='#fbf5e7')

for i, col in enumerate(area_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col], color='#021841ff', kde=True)
    plt.title(col)
    plt.xlabel("")
    plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
corr = df.corr()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
fig = plt.figure(figsize = (12, 4))

plt.subplot(1, 3, 1)
plt.title('View distribution')
sns.countplot(x='view', data=df, color = '#021841ff')

plt.subplot(1, 3, 2)
plt.title('View vs price')
n_colors = len(df['view'].unique())
palette = sns.color_palette("coolwarm", n_colors=n_colors)
sns.boxplot(x='view', y='price', data=df, palette=palette)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-68577014.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='view', y='price', data=df, palette=palette)

# %%
fig = plt.figure(figsize = (12, 4))

plt.subplot(1, 3, 1)
plt.title('Condition distribution')
sns.countplot(x='condition', data=df, color = '#021841ff')

plt.subplot(1, 3, 2)
plt.title('Condition vs price')
n_colors = len(df['condition'].unique())
palette = sns.color_palette("coolwarm", n_colors=n_colors)
sns.boxplot(x='condition', y='price', data=df, palette=palette)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3213735399.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='condition', y='price', data=df, palette=palette)

# %%
fig = plt.figure(figsize = (12, 4), facecolor = '#fbf5e7')

plt.subplot(1, 2, 1)
plt.title('Grade distribution')
sns.countplot(x='grade', data=df, color = '#021841ff')

plt.subplot(1, 2, 2)
plt.title('Grade vs price')
n_colors = len(df['grade'].unique())
palette = sns.color_palette("coolwarm", n_colors=n_colors)
sns.boxplot(x='grade', y='price', data=df, palette=palette)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1459654734.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='grade', y='price', data=df, palette=palette)

# %%
import geopandas as gpd
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df['long'], df['lat'])]

gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
gdf.plot(
    column='price',
    cmap='coolwarm',
    markersize=5,
    legend=True
)

plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title("House Prices by Location")
plt.show()

# %%
price_corr_sorted = df.corr()['price'].sort_values(ascending=False)
price_corr_sorted
# Out:
# price            1.000000
# sqft_living      0.700933
# grade            0.664266
# sqft_above       0.602648
# sqft_living15    0.581781
# bathrooms        0.525487
# view             0.390534
# sqft_basement    0.320301
# lat              0.310008
# bedrooms         0.304454
# floors           0.251428
# waterfront       0.245221
# yr_renovated     0.133075
# sqft_lot         0.088526
# sqft_lot15       0.076060
# yr_built         0.048307
# condition        0.031333
# long             0.024279
# zipcode         -0.054517
# Name: price, dtype: float64
